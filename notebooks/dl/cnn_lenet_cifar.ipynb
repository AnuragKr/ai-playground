# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
#torch.use_deterministic_algorithms(True) #to ensure the reproducibility

# %% [markdown]
# # Defining Model Architecture
#
# ![Screenshot 2025-04-16 at 9.15.10 PM.png](data:image/png;base64,...)

# %%
class LeNet(nn.Module):
  def __init__(self):
    super(LeNet, self).__init__()
    # 3 input image channel, 6 output
    # feature maps and 5x5 conv kernel
    self.cn1 = nn.Conv2d(3,6,5)
    # 6 input image channel, 16 output
    # feature maps and 5x5 conv kernel
    self.cn2 = nn.Conv2d(6,16,5)
    # fully connected Layers of size 120, 84 and 10
    # 5*5 is the spatial dimension at this Layer
    self.fc1 = nn.Linear(16*5*5,120)
    self.fc2 = nn.Linear(120,84)
    self.fc3 = nn.Linear(84,10)

  def forward(self,x):
    # Convolution with 5x5 kernel
    x = F.relu(self.cn1(x))
    # Max pooling over a (2,2) window
    x = F.max_pool2d(x,(2,2))
    # Convolution with 5x5 kernel
    x = F.relu(self.cn2(x))
    # Max pooling over a (2,2) window
    x = F.max_pool2d(x,(2,2))
    #Flatten spatial and depth dimensions
    # into a single vector
    x = x.view(-1,self.flattened_features(x))
    # Fully connected layers
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x

  def flattened_features(self,x):
    size = x.size()[1:]
    num_features = 1
    for s in size:
      num_features *= s
    return num_features

lenet = LeNet()
print(lenet)
# Out:
# LeNet(
#   (cn1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (cn2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %% [markdown]
# # Training Routine

# %%
def train(model,trainloader,optim,epoch):
  # initialize loss
  loss_total = 0.0
  for i, data in enumerate(trainloader, 0):
    # get the inputs; data is a list of [inputs, labels]
    # ip refers to the input images, and ground_truth
    # refers to the output classes the images belong to
    ip, ground_truth = data # unpack the image and label tensors
    ip, ground_truth = ip.to(device), ground_truth.to(device) # move to device
    # zero the parameter gradients
    optim.zero_grad()
    # forward-pass + backward-pass + optimization-step
    op = model(ip)
    loss = nn.CrossEntropyLoss()(op,ground_truth)
    loss.backward()
    optim.step()
    # update loss
    loss_total += loss.item()
    # print Loss statistics
    if (i+1) % 1000 == 0:
      # print at the interval of 1000 mini-batches
      print('[Epoch number : %d, Mini-batches: %5d]\
              loss: %.3f' % (epoch + 1, i + 1, loss_total / 200))
      loss_total = 0.0
  print('Finished Training')

# %% [markdown]
# # Testing Routine

# %%
def test(model, testloader):
  success = 0
  counter = 0
  with torch.no_grad():
    for data in testloader:
      ip, ground_truth = data # unpack the image and label tensors
      ip, ground_truth = ip.to(device), ground_truth.to(device) # move to device
      op = model(ip)
      _, predicted = torch.max(op.data, 1)
      success += (predicted == ground_truth).sum().item()
      counter += ground_truth.size(0)
  print('LeNet accuracy on 10000 images from test dataset: %d %%'\
        % (100 * success / counter))

# %% [markdown]
# # Data Loader

# %%
# The mean and std are kept as 0.5 for normalizing
# pixel values as the pixel values are originally
# in the range 0 to 1
train_transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(),
     transforms.RandomCrop(32,4),
     transforms.ToTensor(),
     transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True,
                                        transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=8,
                                          shuffle=True)
test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.5,0.5,0.5),
                                      (0.5,0.5,0.5))])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True,
                                       transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=10000,
                                         shuffle=False)
# ordering is important
classes = ('plane','car','bird','cat','deer','dog','frog','horse',
           'ship','truck')
# Out:
# 100%|██████████| 170M/170M [00:12<00:00, 13.3MB/s]

# %% [markdown]
# # Investigating Data

# %%
# define a function that displays an image
def imageshow(image):
  # un-normalize the image
  image = image/2 +0.5
  npimage = image.numpy()
  plt.imshow(np.transpose(npimage,(1,2,0)))
  plt.show()

# smaple images from training set
dataiter = iter(trainloader)
images, labels = next(dataiter)
# display images in a grid
num_images = 4
imageshow(torchvision.utils.make_grid(images[:num_images]))
# print Labels
print("     '+'    ||  ".join(classes[labels[j]]  for j in range(num_images)))
# Out:
# bird     '+'    ||  bird     '+'    ||  truck     '+'    ||  ship

# %% [markdown]
# # Training LeNet

# %%
# define optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
lenet = LeNet().to(device)
optim = torch.optim.Adam(lenet.parameters(), lr=0.001)
# training Loop over the dataset multple times
for epoch in range(10):
  train(lenet,trainloader,optim,epoch)
  print()
  test(lenet,testloader)
  print()
print('Finsished Training')
# Out:
# [Epoch number : 1, Mini-batches:  1000]              loss: 10.093
# [Epoch number : 1, Mini-batches:  2000]              loss: 8.797
# [Epoch number : 1, Mini-batches:  3000]              loss: 8.323
# [Epoch number : 1, Mini-batches:  4000]              loss: 8.057
# [Epoch number : 1, Mini-batches:  5000]              loss: 7.791
# [Epoch number : 1, Mini-batches:  6000]              loss: 7.706
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 44 %
#
# [Epoch number : 2, Mini-batches:  1000]              loss: 7.513
# [Epoch number : 2, Mini-batches:  2000]              loss: 7.517
# [Epoch number : 2, Mini-batches:  3000]              loss: 7.301
# [Epoch number : 2, Mini-batches:  4000]              loss: 7.304
# [Epoch number : 2, Mini-batches:  5000]              loss: 7.252
# [Epoch number : 2, Mini-batches:  6000]              loss: 7.116
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 51 %
#
# [Epoch number : 3, Mini-batches:  1000]              loss: 6.997
# [Epoch number : 3, Mini-batches:  2000]              loss: 6.930
# [Epoch number : 3, Mini-batches:  3000]              loss: 6.801
# [Epoch number : 3, Mini-batches:  4000]              loss: 6.819
# [Epoch number : 3, Mini-batches:  5000]              loss: 6.799
# [Epoch number : 3, Mini-batches:  6000]              loss: 6.736
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 54 %
#
# [Epoch number : 4, Mini-batches:  1000]              loss: 6.570
# [Epoch number : 4, Mini-batches:  2000]              loss: 6.491
# [Epoch number : 4, Mini-batches:  3000]              loss: 6.587
# [Epoch number : 4, Mini-batches:  4000]              loss: 6.570
# [Epoch number : 4, Mini-batches:  5000]              loss: 6.496
# [Epoch number : 4, Mini-batches:  6000]              loss: 6.456
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 57 %
#
# [Epoch number : 5, Mini-batches:  1000]              loss: 6.374
# [Epoch number : 5, Mini-batches:  2000]              loss: 6.367
# [Epoch number : 5, Mini-batches:  3000]              loss: 6.282
# [Epoch number : 5, Mini-batches:  4000]              loss: 6.223
# [Epoch number : 5, Mini-batches:  5000]              loss: 6.315
# [Epoch number : 5, Mini-batches:  6000]              loss: 6.301
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 57 %
#
# [Epoch number : 6, Mini-batches:  1000]              loss: 6.121
# [Epoch number : 6, Mini-batches:  2000]              loss: 6.268
# [Epoch number : 6, Mini-batches:  3000]              loss: 6.156
# [Epoch number : 6, Mini-batches:  4000]              loss: 6.085
# [Epoch number : 6, Mini-batches:  5000]              loss: 6.180
# [Epoch number : 6, Mini-batches:  6000]              loss: 6.115
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 7, Mini-batches:  1000]              loss: 6.138
# [Epoch number : 7, Mini-batches:  2000]              loss: 6.089
# [Epoch number : 7, Mini-batches:  3000]              loss: 6.083
# [Epoch number : 7, Mini-batches:  4000]              loss: 5.991
# [Epoch number : 7, Mini-batches:  5000]              loss: 6.058
# [Epoch number : 7, Mini-batches:  6000]              loss: 6.013
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 8, Mini-batches:  1000]              loss: 6.048
# [Epoch number : 8, Mini-batches:  2000]              loss: 5.982
# [Epoch number : 8, Mini-batches:  3000]              loss: 5.850
# [Epoch number : 8, Mini-batches:  4000]              loss: 5.870
# [Epoch number : 8, Mini-batches:  5000]              loss: 5.961
# [Epoch number : 8, Mini-batches:  6000]              loss: 5.889
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 9, Mini-batches:  1000]              loss: 5.861
# [Epoch number : 9, Mini-batches:  2000]              loss: 5.790
# [Epoch number : 9, Mini-batches:  3000]              loss: 5.860
# [Epoch number : 9, Mini-batches:  4000]              loss: 5.886
# [Epoch number : 9, Mini-batches:  5000]              loss: 5.811
# [Epoch number : 9, Mini-batches:  6000]              loss: 5.801
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 10, Mini-batches:  1000]              loss: 5.889
# [Epoch number : 10, Mini-batches:  2000]              loss: 5.760
# [Epoch number : 10, Mini-batches:  3000]              loss: 5.727
# [Epoch number : 10, Mini-batches:  4000]              loss: 5.823
# [Epoch number : 10, Mini-batches:  5000]              loss: 5.743
# [Epoch number : 10, Mini-batches:  6000]              loss: 5.771
# Finished Training
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# Finsished Training

# %% [markdown]
# # Saving the model

# %%
model_path = './cifar_model.pth'
torch.save(lenet.state_dict(), model_path)

# %% [markdown]
# # Testing LeNet

# %%
# Load test dataset images
d_iter = iter(testloader)
im, ground_truth = next(d_iter)
# print images and ground truth
imageshow(torchvision.utils.make_grid(im[:4]))
print('Label:   ',' '.join('%5s'% classes[ground_truth[j]]
                           for j in range(4)))
# Load model
lenet_cached = LeNet()
lenet_cached.load_state_dict(torch.load(model_path))
# model inference
op = lenet_cached(im)
# print predictions
_, pred = torch.max(op,1)
print('Predictions:   ',' '.join('%5s'% classes[pred[j]]
                           for j in range(4)))
# Out:
# Label:      cat  ship  ship plane
# Predictions:      cat   car   car   car

# %%
success = 0
counter = 0
with torch.no_grad():
  for data in testloader:
    im, ground_truth = data
    op = lenet_cached(im)
    _,pred = torch.max(op.data, 1)
    counter += ground_truth.size(0)
    success += (pred == ground_truth).sum().item()
print('Model accuracy on 10000 images from test dataset: %d %%'\
      % (100 * success / counter))
# Out:
# Model accuracy on 10000 images from test dataset: 61 %

# %%
# calculating per class accuracy
class_success = list(0. for i in range(10))
class_counter = list(0. for i in range(10))
with torch.no_grad():
  for data in testloader:
    im, ground_truth = data
    op = lenet_cached(im)
    _, pred = torch.max(op, 1)
    c = (pred == ground_truth).squeeze()
    for i in range(10000):
      ground_truth_curr = ground_truth[i]
      class_success[ground_truth_curr] += c[i].item()
      class_counter[ground_truth_curr] += 1

for i in range(10):

  print('Model accuracy for class %5s : %2d ' % (
      classes[i], 100 * class_success[i] / class_counter[i]))
